# %% [markdown]
# # Anytown GNN
# #### Version: 1
# #### Branch: main

# %% [markdown]
# ## Import

# %%
import wntr
import pandas as pd
import numpy as np
import pickle
import networkx as nx

import torch
import torch.nn.functional as F
from torch_geometric.data import Data, DataLoader
from torch_geometric.utils import convert
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid

# %% [markdown]
# ## Load inp(s) into graphs

# %%
# Create a water network model
inp_file = 'Working files/Mod_AnyT_0.inp'
wn_current_WDS = wntr.network.WaterNetworkModel(inp_file)

# Graph the network
wntr.graphics.plot_network(wn_current_WDS, title=wn_current_WDS.name)
# Out:
# (<matplotlib.collections.PathCollection at 0x22bbe5d6a60>,
#  <matplotlib.collections.LineCollection at 0x22bbe5fb250>)

# %%
G_WDS = wn_current_WDS.get_graph() # directed multigraph

# %%
uG_WDS = G_WDS.to_undirected()

# %%
sG_WDS = nx.Graph(G_WDS)
type(sG_WDS)
# Out:
# networkx.classes.graph.Graph

# %%
sG_WDS.nodes
# Out:
# NodeView(('20', '30', '40', '50', '55', '60', '70', '75', '80', '90', '100', '110', '115', '120', '130', '140', '150', '160', '170', '65', '165'))

# %%
nx.draw(sG_WDS)

# %%
pg_sG_WDS = convert.from_networkx(sG_WDS)

# %%
pg_sG_WDS
# Out:
# Data(edge_index=[2, 80], pos=[21, 2], type=[80])

# %%
np.unique(pg_sG_WDS.type)
# Out:
# array(['Pipe'], dtype='<U4')

# %%
pg_sG_WDS.pos
# Out:
# tensor([[6391.6001, 4257.8101],
#         [6723.6299, 6181.6401],
#         [5327.1499, 7500.0000],
#         [3959.9600, 7050.7798],
#         [3081.0500, 7431.6401],
#         [5366.2100, 6044.9199],
#         [5473.6299, 4931.6401],
#         [2270.5100, 7089.8398],
#         [4340.8198, 6230.4702],
#         [4838.8701, 5410.1602],
#         [4428.7100, 4765.6299],
#         [4125.9800, 3945.3101],
#         [1655.2700, 6787.1099],
#         [3413.0901, 3281.2500],
#         [2055.6599, 3896.4800],
#         [2124.0200, 6015.6299],
#         [3891.6001, 5566.4102],
#         [2895.5100, 4765.6299],
#         [ 825.2000, 5126.9502],
#         [5297.8501, 6367.1899],
#         [2377.9299, 4892.5801]])

# %%
pg_sG_WDS
# Out:
# Data(edge_index=[2, 80], pos=[21, 2], type=[80])

# %%
database = pickle.load( open( "Mod_AnyT_DB_trial.p", "rb" ) )

#data_list = [Data(...), ..., Data(...)]
#loader = DataLoader(data_list, batch_size=32)

# %%
diams_matrix = np.array([np.array(xi).T for xi in database['Diams']]).reshape(100, 40)

# %%
diams_matrix.shape
# Out:
# (100, 40)

# %%
diams_matrix[0] == database['Diams'][0].T
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
diams_x = torch.tensor(diams_matrix, dtype=torch.double)
diams_x
# Out:
# tensor([[ 6.,  8.,  8.,  ..., 10., 14., 12.],
#         [14., 14., 10.,  ...,  6.,  6., 14.],
#         [14., 14.,  8.,  ...,  6.,  6., 12.],
#         ...,
#         [ 8., 12.,  6.,  ..., 12.,  6., 12.],
#         [10.,  8., 12.,  ..., 10.,  8.,  6.],
#         [10., 10., 14.,  ..., 10.,  6.,  8.]], dtype=torch.float64)

# %%
pg_sG_WDS.diams_x = diams_x

# %%
pg_sG_WDS
# Out:
# Data(diams_x=[100, 40], edge_index=[2, 80], pos=[21, 2], type=[80])

# %%
res_index = torch.tensor(np.array(database['avgPrPa']))
pg_sG_WDS.res_index = res_index.reshape(100,1)

# %%
pg_sG_WDS
# Out:
# Data(diams_x=[100, 40], edge_index=[2, 80], pos=[21, 2], res_index=[100, 1], type=[80])

# %%
size_db = len(res_index)
train = torch.tensor([ 0.7*size_db > i for i in range(size_db)])
test =torch.tensor([not i for i in train])

# %%
pg_sG_WDS.diams_x.type()
# Out:
# 'torch.DoubleTensor'

# %%
pg_sG_WDS.train_mask = train
pg_sG_WDS.test_mask = test

# %%
pg_sG_WDS
# Out:
# Data(diams_x=[100, 40], edge_index=[2, 80], pos=[21, 2], res_index=[100, 1], test_mask=[100], train_mask=[100], type=[80])

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = GCNConv(40, 10) #number of features : 10
        self.conv2 = GCNConv(10, 1) # 10 : number of classes (It's Regression, so only one number)

    def forward(self, data):
        x, edge_index = data.diams_x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)

        return torch.sigmoid(x)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

# %%
model.train()
model.double()
for epoch in range(240):
    optimizer.zero_grad()
    out = model(pg_sG_WDS)
    loss = F.mse_loss(out[pg_sG_WDS.train_mask], pg_sG_WDS.res_index[pg_sG_WDS.train_mask])
    if epoch%20==0:
        print(loss)
    loss.backward()
    optimizer.step()
# Out:
# tensor(0.1594, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0356, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0296, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0259, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0213, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0220, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0229, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0127, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0180, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0244, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0218, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(0.0256, dtype=torch.float64, grad_fn=<MseLossBackward>)

# %%
model.eval()
pred = model(pg_sG_WDS)
# correct = int(pred[pg_sG_WDS.test_mask].eq(data.y[data.test_mask]).sum().item())
# acc = correct / int(data.test_mask.sum())
# print('Accuracy: {:.4f}'.format(acc))

# %%
pred[pg_sG_WDS.test_mask].T
# Out:
# tensor([[0.1200, 0.3438, 0.3798, 0.2514, 0.3798, 0.3798, 0.3798, 0.3798, 0.3798,
#          0.3798, 0.3300, 0.3798, 0.2790, 0.3798, 0.3798, 0.3340, 0.3798, 0.3798,
#          0.3798, 0.3256, 0.3798, 0.1737, 0.3798, 0.3464, 0.3798, 0.3798, 0.3717,
#          0.3798, 0.2737, 0.2455]], dtype=torch.float64,
#        grad_fn=<PermuteBackward>)

# %%
pg_sG_WDS.res_index[pg_sG_WDS.test_mask].T
# Out:
# tensor([[ 0.1770, -0.1278,  0.5293,  0.3010,  0.3774,  0.4654,  0.4442,  0.4355,
#           0.3690,  0.4650,  0.3275,  0.4241,  0.3608,  0.4901,  0.3408,  0.4438,
#           0.3784,  0.3991,  0.4260,  0.3008,  0.4454, -0.1741,  0.2776,  0.3690,
#           0.3745,  0.1946,  0.3665,  0.3874,  0.1933,  0.1659]],
#        dtype=torch.float64)

# %%
pred[pg_sG_WDS.test_mask][0].item()
# Out:
# 0.11999501155255865

# %%
[(np.round(pred[pg_sG_WDS.test_mask][i].item(),4), np.round(pg_sG_WDS.res_index[pg_sG_WDS.test_mask][i].item(),4)) for i in range(30)]
# Out:
# [(0.12, 0.177),
#  (0.3438, -0.1278),
#  (0.3798, 0.5293),
#  (0.2514, 0.301),
#  (0.3798, 0.3774),
#  (0.3798, 0.4654),
#  (0.3798, 0.4442),
#  (0.3798, 0.4355),
#  (0.3798, 0.369),
#  (0.3798, 0.465),
#  (0.33, 0.3275),
#  (0.3798, 0.4241),
#  (0.279, 0.3608),
#  (0.3798, 0.4901),
#  (0.3798, 0.3408),
#  (0.334, 0.4438),
#  (0.3798, 0.3784),
#  (0.3798, 0.3991),
#  (0.3798, 0.426),
#  (0.3256, 0.3008),
#  (0.3798, 0.4454),
#  (0.1737, -0.1741),
#  (0.3798, 0.2776),
#  (0.3464, 0.369),
#  (0.3798, 0.3745),
#  (0.3798, 0.1946),
#  (0.3717, 0.3665),
#  (0.3798, 0.3874),
#  (0.2737, 0.1933),
#  (0.2455, 0.1659)]

# %%
model.parameters
# Out:
# <bound method Module.parameters of Net(
#   (conv1): GCNConv(40, 10)
#   (conv2): GCNConv(10, 1)
# )>

# %%
a = model.parameters()

# %%
next(a)
# Out:
# Parameter containing:
# tensor([ 4.2824e-07, -2.5322e-06, -2.5407e-06, -7.9889e-03, -9.4094e-04,
#         -2.6090e-04, -5.6047e-02, -7.1348e-03,  5.3747e-02, -3.5411e-02],
#        dtype=torch.float64, requires_grad=True)
